# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv("data/test.csv")
weather_test = pd.read_csv("data/weather_test.csv")
building_data = pd.read_csv("data/building_metadata.csv")

# %% [markdown]
# # Working on the test data

# %% [markdown]
# ### 1. Merging all the three test data sets: original_test, building_data, weather_test

# %%
# add building data to the test data
test = pd.merge(test, building_data, on="building_id", how="inner")

# Now merge the data with the weather data
test = pd.merge(test, weather_test, on=["site_id", "timestamp"], how="left")

# %% [markdown]
# # Transforming data and filling na values

# %% [markdown]
# Suppose you have to fill temperature data for a nan temperature value. The best match for this nan value would be the data with the same site_id recorded at the same time. Luckily, we do not have any nan value for site_id or timestamp.

# %%
# sorting_by_site_datetime:
# 1. change the type of datetime from object to 'datetime'
test.timestamp = pd.to_datetime(test.timestamp, format='%Y-%m-%d %H:%M:%S')

# 2. sort w.r.t the site_id and then according to the timestamp for the same site_id
test.sort_values(inplace=True, by=['site_id', 'timestamp'])

# %%
test.isna().sum()
# Out:
# row_id                       0
# building_id                  0
# meter                        0
# timestamp                    0
# site_id                      0
# primary_use                  0
# square_feet                  0
# year_built            24598080
# floor_count           34444320
# air_temperature         221901
# cloud_coverage        19542180
# dew_temperature         260799
# precip_depth_1_hr      7801563
# sea_level_pressure     2516826
# wind_direction         2978663
# wind_speed              302089
# dtype: int64

# %%
prev_values=[]
columns=[]

prev_values.append(test.air_temperature.median())
columns.append("air_temperature")

prev_values.append(test.cloud_coverage.median())
columns.append("cloud_coverage")

prev_values.append(test.dew_temperature.median())
columns.append("dew_temperature")

prev_values.append(test.precip_depth_1_hr.median())
columns.append("precip_depth_1_hr")

prev_values.append(test.sea_level_pressure.median())
columns.append("sea_level_pressure")

prev_values.append(test.wind_direction.median())
columns.append("wind_direction")

prev_values.append(test.wind_speed.median())
columns.append("wind_speed")

# %%
for row in test.itertuples():
    row_ind = row.Index
    for i in range(len(columns)):
        if (str(test.at[row_ind, columns[i]])=='nan'):
            test.at[row_ind, columns[i]] = prev_values[i]
        else:
            prev_values[i] = test.at[row_ind, columns[i]]

# %%
# Fill year_built and floor_count with median values
floor_count_median = test.floor_count.median()
year_built_median = test.year_built.median()
test.floor_count.fillna(floor_count_median, inplace=True)
test.year_built.fillna(year_built_median, inplace=True)

# %%
test.isna().sum()
# Out:
# row_id                0
# building_id           0
# meter                 0
# timestamp             0
# site_id               0
# primary_use           0
# square_feet           0
# year_built            0
# floor_count           0
# air_temperature       0
# cloud_coverage        0
# dew_temperature       0
# precip_depth_1_hr     0
# sea_level_pressure    0
# wind_direction        0
# wind_speed            0
# dtype: int64

# %% [markdown]
# # Now let us work with the train data

# %%
train = pd.read_csv("data/train.csv")
# Out:
#         site_id            timestamp  air_temperature  cloud_coverage  \
# 0             0  2016-01-01 00:00:00             25.0             6.0
# 1             0  2016-01-01 01:00:00             24.4             NaN
# 2             0  2016-01-01 02:00:00             22.8             2.0
# 3             0  2016-01-01 03:00:00             21.1             2.0
# 4             0  2016-01-01 04:00:00             20.0             2.0
# ...         ...                  ...              ...             ...
# 139768       15  2016-12-31 19:00:00              3.0             NaN
# 139769       15  2016-12-31 20:00:00              2.8             2.0
# 139770       15  2016-12-31 21:00:00              2.8             NaN
# 139771       15  2016-12-31 22:00:00              2.2             NaN
# 139772       15  2016-12-31 23:00:00              1.7             NaN
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 0                  20.0                NaN              1019.7
# 1                  21.1               -1.0              1020.2
# 2                  21.1                0.0              1020.2
# 3                  20.6                0.0              1020.1
# 4                  20.0               -1.0              1020.0
# ...                 ...                ...                 ...
# 139768             -8.0                NaN                 NaN
# 139769             -8.9                NaN              1007.4
# 139770             -7.2                NaN              1007.5
# 139771             -6.7                NaN              1008.0
# 139772             -5.6               -1.0              1008.5
#
#         wind_direction  wind_speed
# 0                  0.0         0.0
# 1                 70.0         1.5
# 2                  0.0         0.0
# 3                  0.0         0.0
# 4                250.0         2.6
# ...                ...         ...
# 139768           180.0         5.7
# 139769           180.0         7.7
# 139770           180.0         5.1
# 139771           170.0         4.6
# 139772           180.0         8.8
#
# [139773 rows x 9 columns]

# %%
weather_train = pd.read_csv("data/weather_train.csv")

# %% [markdown]
# ## Merge all the three training data sets

# %%
# As mentioned in the kaggle Description, meter_reading for meter-0 is in kBTU and we need to change it to kWh.
train.meter_reading[train.meter==0]*=0.293

# Now merge add the building details to training data
train = pd.merge(train, building_data, on="building_id", how="inner")

# Now add the weather data to the above transformed data
train = pd.merge(train, weather_train, on=["site_id", "timestamp"], how="left")
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_1920\2958664114.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.meter_reading[train.meter==0]*=0.293

# %%
train.isna().sum()
# Out:
# building_id                  0
# meter                        0
# timestamp                    0
# meter_reading                0
# site_id                      0
# primary_use                  0
# square_feet                  0
# year_built            12127645
# floor_count           16709167
# air_temperature          96658
# cloud_coverage         8825365
# dew_temperature         100140
# precip_depth_1_hr      3749023
# sea_level_pressure     1231669
# wind_direction         1449048
# wind_speed              143676
# dtype: int64

# %%
train.dropna(inplace=True)
train.shape
# Out:
# (321728, 16)

# %%
train.isna().sum()
# Out:
# building_id           0
# meter                 0
# timestamp             0
# meter_reading         0
# site_id               0
# primary_use           0
# square_feet           0
# year_built            0
# floor_count           0
# air_temperature       0
# cloud_coverage        0
# dew_temperature       0
# precip_depth_1_hr     0
# sea_level_pressure    0
# wind_direction        0
# wind_speed            0
# dtype: int64

# %%
train.corr()
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_1920\2189804198.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                     building_id  meter  meter_reading  site_id  primary_use  \
# building_id            1.000000    NaN       0.208358      NaN    -0.141665
# meter                       NaN    NaN            NaN      NaN          NaN
# meter_reading          0.208358    NaN       1.000000      NaN    -0.156957
# site_id                     NaN    NaN            NaN      NaN          NaN
# primary_use           -0.141665    NaN      -0.156957      NaN     1.000000
# square_feet            0.195173    NaN       0.612993      NaN     0.004772
# year_built             0.007697    NaN       0.372491      NaN     0.162426
# floor_count            0.187297    NaN       0.626113      NaN    -0.234333
# air_temperature       -0.000437    NaN      -0.015394      NaN    -0.006727
# cloud_coverage         0.001996    NaN      -0.011821      NaN    -0.001853
# dew_temperature       -0.000535    NaN       0.001669      NaN    -0.006549
# precip_depth_1_hr      0.000322    NaN       0.001262      NaN     0.000143
# sea_level_pressure     0.001449    NaN       0.007768      NaN     0.007836
# wind_direction        -0.000150    NaN      -0.030353      NaN    -0.006985
# wind_speed             0.000373    NaN      -0.035744      NaN    -0.006488
#
#                     square_feet  year_built  floor_count  air_temperature  \
# building_id            0.195173    0.007697     0.187297        -0.000437
# meter                       NaN         NaN          NaN              NaN
# meter_reading          0.612993    0.372491     0.626113        -0.015394
# site_id                     NaN         NaN          NaN              NaN
# primary_use            0.004772    0.162426    -0.234333        -0.006727
# square_feet            1.000000    0.265812     0.642057        -0.006530
# year_built             0.265812    1.000000     0.291919         0.005804
# floor_count            0.642057    0.291919     1.000000        -0.001307
# air_temperature       -0.006530    0.005804    -0.001307         1.000000
# cloud_coverage         0.004031   -0.003525     0.006665         0.080004
# dew_temperature       -0.007716    0.007177    -0.002237         0.656597
# precip_depth_1_hr      0.000391   -0.000414     0.000650        -0.002843
# sea_level_pressure     0.008282   -0.008343     0.003118        -0.491020
# wind_direction        -0.003387    0.004841     0.002210         0.498709
# wind_speed            -0.002694    0.004464     0.003141         0.471196
#
#                     cloud_coverage  dew_temperature  precip_depth_1_hr  \
# building_id               0.001996        -0.000535           0.000322
# meter                          NaN              NaN                NaN
# meter_reading            -0.011821         0.001669           0.001262
# site_id                        NaN              NaN                NaN
# primary_use              -0.001853        -0.006549           0.000143
# square_feet               0.004031        -0.007716           0.000391
# year_built               -0.003525         0.007177          -0.000414
# floor_count               0.006665        -0.002237           0.000650
# air_temperature           0.080004         0.656597          -0.002843
# cloud_coverage            1.000000         0.103219           0.015431
# dew_temperature           0.103219         1.000000           0.002094
# precip_depth_1_hr         0.015431         0.002094           1.000000
# sea_level_pressure        0.018659        -0.512211          -0.024584
# wind_direction            0.155951         0.306204          -0.000042
# wind_speed                0.210514         0.199424           0.032822
#
#                     sea_level_pressure  wind_direction  wind_speed
# building_id                   0.001449       -0.000150    0.000373
# meter                              NaN             NaN         NaN
# meter_reading                 0.007768       -0.030353   -0.035744
# site_id                            NaN             NaN         NaN
# primary_use                   0.007836       -0.006985   -0.006488
# square_feet                   0.008282       -0.003387   -0.002694
# year_built                   -0.008343        0.004841    0.004464
# floor_count                   0.003118        0.002210    0.003141
# air_temperature              -0.491020        0.498709    0.471196
# cloud_coverage                0.018659        0.155951    0.210514
# dew_temperature              -0.512211        0.306204    0.199424
# precip_depth_1_hr            -0.024584       -0.000042    0.032822
# sea_level_pressure            1.000000       -0.388235   -0.342276
# wind_direction               -0.388235        1.000000    0.636827
# wind_speed                   -0.342276        0.636827    1.000000

# %%
# convert primary_use to categorical
train.primary_use = train.primary_use.astype("category").cat.codes

# %%
train.head()
# Out:
#          building_id  meter           timestamp  meter_reading  site_id  \
# 6485009          565      0 2016-01-01 01:00:00        2.49050        4
# 6485010          565      0 2016-01-01 02:00:00        2.12425        4
# 6485011          565      0 2016-01-01 03:00:00        2.19750        4
# 6485012          565      0 2016-01-01 04:00:00        2.34400        4
# 6485013          565      0 2016-01-01 05:00:00        2.05100        4
#
#          primary_use  square_feet  year_built  floor_count  air_temperature  \
# 6485009            0        15326      1954.0          2.0              9.4
# 6485010            0        15326      1954.0          2.0              8.3
# 6485011            0        15326      1954.0          2.0              7.8
# 6485012            0        15326      1954.0          2.0              5.0
# 6485013            0        15326      1954.0          2.0              5.6
#
#          ...  dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 6485009  ...             -2.2                0.0              1021.4
# 6485010  ...             -2.8                0.0              1021.6
# 6485011  ...             -2.8                0.0              1021.7
# 6485012  ...             -0.6                0.0              1021.8
# 6485013  ...             -1.1                0.0              1021.6
#
#          wind_direction  wind_speed  Year  Month  Week  Day  hour
# 6485009           360.0         3.1  2016      1    53    1     1
# 6485010             0.0         0.0  2016      1    53    1     2
# 6485011            90.0         1.5  2016      1    53    1     3
# 6485012             0.0         0.0  2016      1    53    1     4
# 6485013           130.0         3.1  2016      1    53    1     5
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Modifying the date and time property

# %%
train.timestamp = pd.to_datetime(train.timestamp, format='%Y-%m-%d %H:%M:%S')
train["Year"] = train.timestamp.dt.year
train["Month"] = train.timestamp.dt.month
train["Week"] = train.timestamp.dt.week
train["Day"] = train.timestamp.dt.day
train["hour"] = train.timestamp.dt.hour
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_1920\349208782.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   train["Week"] = train.timestamp.dt.week

# %%
train.T
# Out:
#                                6485009              6485010   \
# building_id                         565                  565
# meter                                 0                    0
# timestamp           2016-01-01 01:00:00  2016-01-01 02:00:00
# meter_reading                    2.4905              2.12425
# site_id                               4                    4
# primary_use                           0                    0
# square_feet                       15326                15326
# year_built                       1954.0               1954.0
# floor_count                         2.0                  2.0
# air_temperature                     9.4                  8.3
# cloud_coverage                      0.0                  0.0
# dew_temperature                    -2.2                 -2.8
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1021.4               1021.6
# wind_direction                    360.0                  0.0
# wind_speed                          3.1                  0.0
# Year                               2016                 2016
# Month                                 1                    1
# Week                                 53                   53
# Day                                   1                    1
# hour                                  1                    2
#
#                                6485011              6485012   \
# building_id                         565                  565
# meter                                 0                    0
# timestamp           2016-01-01 03:00:00  2016-01-01 04:00:00
# meter_reading                    2.1975                2.344
# site_id                               4                    4
# primary_use                           0                    0
# square_feet                       15326                15326
# year_built                       1954.0               1954.0
# floor_count                         2.0                  2.0
# air_temperature                     7.8                  5.0
# cloud_coverage                      0.0                  0.0
# dew_temperature                    -2.8                 -0.6
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1021.7               1021.8
# wind_direction                     90.0                  0.0
# wind_speed                          1.5                  0.0
# Year                               2016                 2016
# Month                                 1                    1
# Week                                 53                   53
# Day                                   1                    1
# hour                                  3                    4
#
#                                6485013              6485014   \
# building_id                         565                  565
# meter                                 0                    0
# timestamp           2016-01-01 05:00:00  2016-01-01 06:00:00
# meter_reading                     2.051               2.4905
# site_id                               4                    4
# primary_use                           0                    0
# square_feet                       15326                15326
# year_built                       1954.0               1954.0
# floor_count                         2.0                  2.0
# air_temperature                     5.6                  5.0
# cloud_coverage                      0.0                  0.0
# dew_temperature                    -1.1                 -1.1
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1021.6               1021.6
# wind_direction                    130.0                160.0
# wind_speed                          3.1                  1.5
# Year                               2016                 2016
# Month                                 1                    1
# Week                                 53                   53
# Day                                   1                    1
# hour                                  5                    6
#
#                                6485016              6485017   \
# building_id                         565                  565
# meter                                 0                    0
# timestamp           2016-01-01 08:00:00  2016-01-01 09:00:00
# meter_reading                     2.051                2.344
# site_id                               4                    4
# primary_use                           0                    0
# square_feet                       15326                15326
# year_built                       1954.0               1954.0
# floor_count                         2.0                  2.0
# air_temperature                     4.4                  4.4
# cloud_coverage                      0.0                  0.0
# dew_temperature                    -2.2                 -4.4
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1020.9               1020.5
# wind_direction                      0.0                 20.0
# wind_speed                          0.0                  2.1
# Year                               2016                 2016
# Month                                 1                    1
# Week                                 53                   53
# Day                                   1                    1
# hour                                  8                    9
#
#                                6485018              6485019   ...  \
# building_id                         565                  565  ...
# meter                                 0                    0  ...
# timestamp           2016-01-01 10:00:00  2016-01-01 11:00:00  ...
# meter_reading                     2.051              2.12425  ...
# site_id                               4                    4  ...
# primary_use                           0                    0  ...
# square_feet                       15326                15326  ...
# year_built                       1954.0               1954.0  ...
# floor_count                         2.0                  2.0  ...
# air_temperature                     4.4                  4.4  ...
# cloud_coverage                      0.0                  0.0  ...
# dew_temperature                    -6.7                 -7.8  ...
# precip_depth_1_hr                   0.0                  0.0  ...
# sea_level_pressure               1020.8               1020.7  ...
# wind_direction                     20.0                 30.0  ...
# wind_speed                          2.1                  2.6  ...
# Year                               2016                 2016  ...
# Month                                 1                    1  ...
# Week                                 53                   53  ...
# Day                                   1                    1  ...
# hour                                 10                   11  ...
#
#                                20212937             20212938  \
# building_id                         591                  591
# meter                                 0                    0
# timestamp           2016-12-30 21:00:00  2016-12-30 22:00:00
# meter_reading                  4.468631             4.175221
# site_id                               4                    4
# primary_use                           1                    1
# square_feet                       59326                59326
# year_built                       1932.0               1932.0
# floor_count                         1.0                  1.0
# air_temperature                    12.8                 14.4
# cloud_coverage                      4.0                  2.0
# dew_temperature                     7.2                  5.0
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1016.5               1015.5
# wind_direction                    210.0                  0.0
# wind_speed                          2.1                  0.0
# Year                               2016                 2016
# Month                                12                   12
# Week                                 52                   52
# Day                                  30                   30
# hour                                 21                   22
#
#                                20212940             20212941  \
# building_id                         591                  591
# meter                                 0                    0
# timestamp           2016-12-31 00:00:00  2016-12-31 01:00:00
# meter_reading                  3.662119             3.807769
# site_id                               4                    4
# primary_use                           1                    1
# square_feet                       59326                59326
# year_built                       1932.0               1932.0
# floor_count                         1.0                  1.0
# air_temperature                    12.2                 11.7
# cloud_coverage                      2.0                  2.0
# dew_temperature                     6.1                  8.9
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1014.4               1014.4
# wind_direction                    210.0                290.0
# wind_speed                          3.1                  4.1
# Year                               2016                 2016
# Month                                12                   12
# Week                                 52                   52
# Day                                  31                   31
# hour                                  0                    1
#
#                                20212942             20212951  \
# building_id                         591                  591
# meter                                 0                    0
# timestamp           2016-12-31 02:00:00  2016-12-31 11:00:00
# meter_reading                  3.810787             4.468279
# site_id                               4                    4
# primary_use                           1                    1
# square_feet                       59326                59326
# year_built                       1932.0               1932.0
# floor_count                         1.0                  1.0
# air_temperature                    11.1                 10.0
# cloud_coverage                      4.0                  4.0
# dew_temperature                     8.9                  3.3
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1014.2               1013.0
# wind_direction                    280.0                240.0
# wind_speed                          1.5                  3.6
# Year                               2016                 2016
# Month                                12                   12
# Week                                 52                   52
# Day                                  31                   31
# hour                                  2                   11
#
#                                20212952             20212955  \
# building_id                         591                  591
# meter                                 0                    0
# timestamp           2016-12-31 12:00:00  2016-12-31 15:00:00
# meter_reading                  4.468602             4.540592
# site_id                               4                    4
# primary_use                           1                    1
# square_feet                       59326                59326
# year_built                       1932.0               1932.0
# floor_count                         1.0                  1.0
# air_temperature                     9.4                  7.2
# cloud_coverage                      2.0                  4.0
# dew_temperature                     3.3                  4.4
# precip_depth_1_hr                   0.0                 -1.0
# sea_level_pressure               1013.1               1013.1
# wind_direction                    240.0                130.0
# wind_speed                          2.1                  2.6
# Year                               2016                 2016
# Month                                12                   12
# Week                                 52                   52
# Day                                  31                   31
# hour                                 12                   15
#
#                                20212956             20212963
# building_id                         591                  591
# meter                                 0                    0
# timestamp           2016-12-31 16:00:00  2016-12-31 23:00:00
# meter_reading                  4.103055             3.443512
# site_id                               4                    4
# primary_use                           1                    1
# square_feet                       59326                59326
# year_built                       1932.0               1932.0
# floor_count                         1.0                  1.0
# air_temperature                     7.2                 12.8
# cloud_coverage                      2.0                  2.0
# dew_temperature                     3.9                  3.3
# precip_depth_1_hr                   0.0                  0.0
# sea_level_pressure               1013.2               1013.6
# wind_direction                    120.0                 30.0
# wind_speed                          3.6                  2.1
# Year                               2016                 2016
# Month                                12                   12
# Week                                 52                   52
# Day                                  31                   31
# hour                                 16                   23
#
# [21 rows x 321728 columns]

# %%
# Note that 1. building_id, timestamp and site_id do not have any direct impact so we'll remove them
train.drop(columns=["building_id", "timestamp", "site_id"], inplace=True)

# %%
train.T
# Out:
#                       6485009      6485010     6485011    6485012    6485013   \
# meter                   0.0000      0.00000      0.0000      0.000      0.000
# meter_reading           2.4905      2.12425      2.1975      2.344      2.051
# primary_use             0.0000      0.00000      0.0000      0.000      0.000
# square_feet         15326.0000  15326.00000  15326.0000  15326.000  15326.000
# year_built           1954.0000   1954.00000   1954.0000   1954.000   1954.000
# floor_count             2.0000      2.00000      2.0000      2.000      2.000
# air_temperature         9.4000      8.30000      7.8000      5.000      5.600
# cloud_coverage          0.0000      0.00000      0.0000      0.000      0.000
# dew_temperature        -2.2000     -2.80000     -2.8000     -0.600     -1.100
# precip_depth_1_hr       0.0000      0.00000      0.0000      0.000      0.000
# sea_level_pressure   1021.4000   1021.60000   1021.7000   1021.800   1021.600
# wind_direction        360.0000      0.00000     90.0000      0.000    130.000
# wind_speed              3.1000      0.00000      1.5000      0.000      3.100
# Year                 2016.0000   2016.00000   2016.0000   2016.000   2016.000
# Month                   1.0000      1.00000      1.0000      1.000      1.000
# Week                   53.0000     53.00000     53.0000     53.000     53.000
# Day                     1.0000      1.00000      1.0000      1.000      1.000
# hour                    1.0000      2.00000      3.0000      4.000      5.000
#
#                       6485014    6485016    6485017    6485018      6485019   \
# meter                   0.0000      0.000      0.000      0.000      0.00000
# meter_reading           2.4905      2.051      2.344      2.051      2.12425
# primary_use             0.0000      0.000      0.000      0.000      0.00000
# square_feet         15326.0000  15326.000  15326.000  15326.000  15326.00000
# year_built           1954.0000   1954.000   1954.000   1954.000   1954.00000
# floor_count             2.0000      2.000      2.000      2.000      2.00000
# air_temperature         5.0000      4.400      4.400      4.400      4.40000
# cloud_coverage          0.0000      0.000      0.000      0.000      0.00000
# dew_temperature        -1.1000     -2.200     -4.400     -6.700     -7.80000
# precip_depth_1_hr       0.0000      0.000      0.000      0.000      0.00000
# sea_level_pressure   1021.6000   1020.900   1020.500   1020.800   1020.70000
# wind_direction        160.0000      0.000     20.000     20.000     30.00000
# wind_speed              1.5000      0.000      2.100      2.100      2.60000
# Year                 2016.0000   2016.000   2016.000   2016.000   2016.00000
# Month                   1.0000      1.000      1.000      1.000      1.00000
# Week                   53.0000     53.000     53.000     53.000     53.00000
# Day                     1.0000      1.000      1.000      1.000      1.00000
# hour                    6.0000      8.000      9.000     10.000     11.00000
#
#                     ...      20212937      20212938      20212940  \
# meter               ...      0.000000      0.000000      0.000000
# meter_reading       ...      4.468631      4.175221      3.662119
# primary_use         ...      1.000000      1.000000      1.000000
# square_feet         ...  59326.000000  59326.000000  59326.000000
# year_built          ...   1932.000000   1932.000000   1932.000000
# floor_count         ...      1.000000      1.000000      1.000000
# air_temperature     ...     12.800000     14.400000     12.200000
# cloud_coverage      ...      4.000000      2.000000      2.000000
# dew_temperature     ...      7.200000      5.000000      6.100000
# precip_depth_1_hr   ...      0.000000      0.000000      0.000000
# sea_level_pressure  ...   1016.500000   1015.500000   1014.400000
# wind_direction      ...    210.000000      0.000000    210.000000
# wind_speed          ...      2.100000      0.000000      3.100000
# Year                ...   2016.000000   2016.000000   2016.000000
# Month               ...     12.000000     12.000000     12.000000
# Week                ...     52.000000     52.000000     52.000000
# Day                 ...     30.000000     30.000000     31.000000
# hour                ...     21.000000     22.000000      0.000000
#
#                         20212941      20212942      20212951      20212952  \
# meter                   0.000000      0.000000      0.000000      0.000000
# meter_reading           3.807769      3.810787      4.468279      4.468602
# primary_use             1.000000      1.000000      1.000000      1.000000
# square_feet         59326.000000  59326.000000  59326.000000  59326.000000
# year_built           1932.000000   1932.000000   1932.000000   1932.000000
# floor_count             1.000000      1.000000      1.000000      1.000000
# air_temperature        11.700000     11.100000     10.000000      9.400000
# cloud_coverage          2.000000      4.000000      4.000000      2.000000
# dew_temperature         8.900000      8.900000      3.300000      3.300000
# precip_depth_1_hr       0.000000      0.000000      0.000000      0.000000
# sea_level_pressure   1014.400000   1014.200000   1013.000000   1013.100000
# wind_direction        290.000000    280.000000    240.000000    240.000000
# wind_speed              4.100000      1.500000      3.600000      2.100000
# Year                 2016.000000   2016.000000   2016.000000   2016.000000
# Month                  12.000000     12.000000     12.000000     12.000000
# Week                   52.000000     52.000000     52.000000     52.000000
# Day                    31.000000     31.000000     31.000000     31.000000
# hour                    1.000000      2.000000     11.000000     12.000000
#
#                         20212955      20212956      20212963
# meter                   0.000000      0.000000      0.000000
# meter_reading           4.540592      4.103055      3.443512
# primary_use             1.000000      1.000000      1.000000
# square_feet         59326.000000  59326.000000  59326.000000
# year_built           1932.000000   1932.000000   1932.000000
# floor_count             1.000000      1.000000      1.000000
# air_temperature         7.200000      7.200000     12.800000
# cloud_coverage          4.000000      2.000000      2.000000
# dew_temperature         4.400000      3.900000      3.300000
# precip_depth_1_hr      -1.000000      0.000000      0.000000
# sea_level_pressure   1013.100000   1013.200000   1013.600000
# wind_direction        130.000000    120.000000     30.000000
# wind_speed              2.600000      3.600000      2.100000
# Year                 2016.000000   2016.000000   2016.000000
# Month                  12.000000     12.000000     12.000000
# Week                   52.000000     52.000000     52.000000
# Day                    31.000000     31.000000     31.000000
# hour                   15.000000     16.000000     23.000000
#
# [18 rows x 321728 columns]

# %% [markdown]
# ## Let us now train a model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop("meter_reading", axis=1), train.meter_reading)

# %%
clf = RandomForestRegressor(n_jobs=-1)
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9954514977732327

# %%
y_preds = clf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_log_error

# %%
mean_squared_log_error(y_test, y_preds)
# Out:
# 0.017352983943522776

# %%
test.dtypes
# Out:
# row_id                         int64
# building_id                    int64
# meter                          int64
# timestamp             datetime64[ns]
# site_id                        int64
# primary_use                     int8
# square_feet                    int64
# year_built                   float64
# floor_count                  float64
# air_temperature              float64
# cloud_coverage               float64
# dew_temperature              float64
# precip_depth_1_hr            float64
# sea_level_pressure           float64
# wind_direction               float64
# wind_speed                   float64
# Year                           int64
# Month                          int64
# Week                           int64
# Day                            int64
# hour                           int64
# dtype: object

# %%
train.dtypes
# Out:
# meter                   int64
# meter_reading         float64
# primary_use              int8
# square_feet             int64
# year_built            float64
# floor_count           float64
# air_temperature       float64
# cloud_coverage        float64
# dew_temperature       float64
# precip_depth_1_hr     float64
# sea_level_pressure    float64
# wind_direction        float64
# wind_speed            float64
# Year                    int64
# Month                   int64
# Week                    int64
# Day                     int64
# hour                    int64
# dtype: object

# %% [markdown]
# ### enrich test data sets with date and time columns

# %%
test["Year"] = test.timestamp.dt.year
test["Month"] = test.timestamp.dt.month
test["Week"] = test.timestamp.dt.week
test["Day"] = test.timestamp.dt.day
test["hour"] = test.timestamp.dt.hour
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_1920\1954988026.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   test["Week"] = test.timestamp.dt.week

# %%
test.shape, train.shape
# Out:
# ((41697600, 21), (321728, 18))

# %% [markdown]
# ## Convert primary use of test from object dtype to categorical

# %%
test.primary_use = test.primary_use.astype("category").cat.codes

# %%
# drop timestamp, site_id and building_id
test.drop(columns=["building_id", "timestamp", "site_id"], inplace=True)

# %%
test
# Out:
#           meter  primary_use  square_feet  year_built  floor_count  \
# 0             0            0         7432      2008.0          3.0
# 17520         0            0         2720      2004.0          3.0
# 35040         0            0         5376      1991.0          3.0
# 52560         0            0        23685      2002.0          3.0
# 70080         0            0       116607      1975.0          3.0
# ...         ...          ...          ...         ...          ...
# 41627519      0            1        19619      1914.0          3.0
# 41645039      0            0         4298      1969.0          3.0
# 41662559      0            1        11265      1997.0          3.0
# 41680079      0            4        29775      2001.0          3.0
# 41697599      0            6        92271      2001.0          3.0
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 0                    17.8             4.0             11.7                0.0
# 17520                17.8             4.0             11.7                0.0
# 35040                17.8             4.0             11.7                0.0
# 52560                17.8             4.0             11.7                0.0
# 70080                17.8             4.0             11.7                0.0
# ...                   ...             ...              ...                ...
# 41627519             13.3             0.0              7.2               -1.0
# 41645039             13.3             0.0              7.2               -1.0
# 41662559             13.3             0.0              7.2               -1.0
# 41680079             13.3             0.0              7.2               -1.0
# 41697599             13.3             0.0              7.2               -1.0
#
#           sea_level_pressure  wind_direction  wind_speed  Year  Month  Week  \
# 0                     1021.4           100.0         3.6  2017      1    52
# 17520                 1021.4           100.0         3.6  2017      1    52
# 35040                 1021.4           100.0         3.6  2017      1    52
# 52560                 1021.4           100.0         3.6  2017      1    52
# 70080                 1021.4           100.0         3.6  2017      1    52
# ...                      ...             ...         ...   ...    ...   ...
# 41627519              1020.8            70.0         2.6  2018      5    19
# 41645039              1020.8            70.0         2.6  2018      5    19
# 41662559              1020.8            70.0         2.6  2018      5    19
# 41680079              1020.8            70.0         2.6  2018      5    19
# 41697599              1020.8            70.0         2.6  2018      5    19
#
#           Day  hour
# 0           1     0
# 17520       1     0
# 35040       1     0
# 52560       1     0
# 70080       1     0
# ...       ...   ...
# 41627519    9     7
# 41645039    9     7
# 41662559    9     7
# 41680079    9     7
# 41697599    9     7
#
# [41697600 rows x 17 columns]

# %%
# Sort the test data w.r.t row_id
test.sort_values(inplace=True, by=['row_id'])

# %%
# Now drop the row_id for training
test.drop(columns='row_id', inplace=True)

# %%
test.shape, X_test.shape
# Out:
# ((41697600, 17), (80432, 17))

# %%
test_preds = clf.predict(test)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 test_preds = clf.predict(test)
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\ensemble\_forest.py:981, in ForestRegressor.predict(self, X)
#     979 check_is_fitted(self)
#     980 # Check data
# --> 981 X = self._validate_X_predict(X)
#     983 # Assign chunk of trees to jobs
#     984 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\ensemble\_forest.py:602, in BaseForest._validate_X_predict(self, X)
#     599 """
#     600 Validate X whenever one tries to predict, apply, predict_proba."""
#     601 check_is_fitted(self)
# --> 602 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     603 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     604     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\base.py:546, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     544     raise ValueError("Validation should be done on X, y or both.")
#     545 elif not no_val_X and no_val_y:
# --> 546     X = check_array(X, input_name="X", **check_params)
#     547     out = X
#     548 elif no_val_X and not no_val_y:
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File ~\DSAI projects\env707\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# File ~\DSAI projects\env707\lib\site-packages\pandas\core\frame.py:971, in DataFrame._values(self)
#     969 blocks = mgr.blocks
#     970 if len(blocks) != 1:
# --> 971     return self.values
#     973 arr = blocks[0].values
#     974 if arr.ndim == 1:
#     975     # non-2D ExtensionArray
#
# File ~\DSAI projects\env707\lib\site-packages\pandas\core\frame.py:11739, in DataFrame.values(self)
#   11666 """
#   11667 Return a Numpy representation of the DataFrame.
#   11668
#    (...)
#   11736        ['monkey', nan, None]], dtype=object)
#   11737 """
#   11738 self._consolidate_inplace()
# > 11739 return self._mgr.as_array()
#
# File ~\DSAI projects\env707\lib\site-packages\pandas\core\internals\managers.py:1770, in BlockManager.as_array(self, dtype, copy, na_value)
#    1768             arr = arr.astype(dtype, copy=False)
#    1769 else:
# -> 1770     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1771     # The underlying data was copied within _interleave
#    1772     copy = False
#
# File ~\DSAI projects\env707\lib\site-packages\pandas\core\internals\managers.py:1809, in BlockManager._interleave(self, dtype, na_value)
#    1806 elif is_dtype_equal(dtype, str):
#    1807     dtype = np.dtype("object")
# -> 1809 result = np.empty(self.shape, dtype=dtype)
#    1811 itemmask = np.zeros(self.shape[0])
#    1813 if dtype == np.dtype("object") and na_value is lib.no_default:
#    1814     # much more performant than using to_numpy below
#
# MemoryError: Unable to allocate 5.28 GiB for an array with shape (17, 41697600) and data type float64

# %%
ans = mean_squared_log_error(test, test_preds)
ans

# %%
train = 1
building_data = 1
weather_test = 1
weather_train = 1

# %%
clf.predict(test).to_csv("hi.csv")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 clf.predict(test).to_csv("hi.csv")
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\ensemble\_forest.py:994, in ForestRegressor.predict(self, X)
#     992 # Parallel loop
#     993 lock = threading.Lock()
# --> 994 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#     995     delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
#     996     for e in self.estimators_
#     997 )
#     999 y_hat /= len(self.estimators_)
#    1001 return y_hat
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\DSAI projects\env707\lib\site-packages\joblib\parallel.py:1061, in Parallel.__call__(self, iterable)
#    1058     self._iterating = False
#    1060 with self._backend.retrieval_context():
# -> 1061     self.retrieve()
#    1062 # Make sure that we get a last message telling us we are done
#    1063 elapsed_time = time.time() - self._start_time
#
# File ~\DSAI projects\env707\lib\site-packages\joblib\parallel.py:938, in Parallel.retrieve(self)
#     936 try:
#     937     if getattr(self._backend, 'supports_timeout', False):
# --> 938         self._output.extend(job.get(timeout=self.timeout))
#     939     else:
#     940         self._output.extend(job.get())
#
# File ~\DSAI projects\env707\lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~\DSAI projects\env707\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~\DSAI projects\env707\lib\site-packages\joblib\_parallel_backends.py:595, in SafeFunction.__call__(self, *args, **kwargs)
#     593 def __call__(self, *args, **kwargs):
#     594     try:
# --> 595         return self.func(*args, **kwargs)
#     596     except KeyboardInterrupt as e:
#     597         # We capture the KeyboardInterrupt and reraise it as
#     598         # something different, as multiprocessing does not
#     599         # interrupt processing for a KeyboardInterrupt
#     600         raise WorkerInterrupt() from e
#
# File ~\DSAI projects\env707\lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\DSAI projects\env707\lib\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\ensemble\_forest.py:650, in _accumulate_prediction(predict, X, out, lock)
#     643 def _accumulate_prediction(predict, X, out, lock):
#     644     """
#     645     This is a utility function for joblib's Parallel.
#     646
#     647     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     648     complains that it cannot pickle it when placed there.
#     649     """
# --> 650     prediction = predict(X, check_input=False)
#     651     with lock:
#     652         if len(out) == 1:
#
# File ~\DSAI projects\env707\lib\site-packages\sklearn\tree\_classes.py:427, in BaseDecisionTree.predict(self, X, check_input)
#     425 check_is_fitted(self)
#     426 X = self._validate_X_predict(X, check_input)
# --> 427 proba = self.tree_.predict(X)
#     428 n_samples = X.shape[0]
#     430 # Classification
#
# File sklearn\tree\_tree.pyx:776, in sklearn.tree._tree.Tree.predict()
#
# File sklearn\tree\_tree.pyx:778, in sklearn.tree._tree.Tree.predict()
#
# MemoryError: Unable to allocate 318. MiB for an array with shape (41697600, 1, 1) and data type float64
